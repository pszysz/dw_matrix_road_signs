# %% [markdown]
# <a href="https://colab.research.google.com/github/pszysz/dw_matrix_road_signs/blob/master/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from skimage import color, exposure

from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
cd '/content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_signs'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_signs

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(
      X_train,
      y_train,
      batch_size=params_fit.get('batch_size', 128),
      epochs=params_fit.get('epochs', 5),
      verbose=params_fit.get('verbose', 1),
      validation_data=params_fit.get('validation_data', (X_train, y_train)),
      callbacks=[tensorboard_callback]
      )
  
  return model

# %%
def predict(model_trained, X_test, y_test, scoring=accuracy_score):
  y_test_norm = np.argmax(y_test, axis=1)
  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)
  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
                    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
                    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
                    MaxPool2D(),
                    Dropout(0.3),
                     
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
                    MaxPool2D(),
                    Dropout(0.3),
                     
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
                    MaxPool2D(),
                    Dropout(0.3),
                    
                    Flatten(),
                     
                    Dense(1024, activation='relu'),
                    Dropout(0.3),
                    
                    Dense(1024, activation='relu'),
                    Dropout(0.3),
                    
                    Dense(num_classes, activation='softmax')
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train)

predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 7s 24ms/step - loss: 2.4041 - accuracy: 0.3403 - val_loss: 0.8670 - val_accuracy: 0.7284
# Epoch 2/5
# 272/272 [==============================] - 6s 23ms/step - loss: 0.8658 - accuracy: 0.7215 - val_loss: 0.2539 - val_accuracy: 0.9250
# Epoch 3/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4249 - accuracy: 0.8668 - val_loss: 0.1045 - val_accuracy: 0.9688
# Epoch 4/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2775 - accuracy: 0.9154 - val_loss: 0.0547 - val_accuracy: 0.9860
# Epoch 5/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2101 - accuracy: 0.9363 - val_loss: 0.0386 - val_accuracy: 0.9886
# 0.9678004535147392

# %%
def get_model(params):
  return Sequential([
                    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
                    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
                    MaxPool2D(),
                    Dropout(params['dropout_cnn_block_one']),
                     
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
                    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
                    MaxPool2D(),
                    Dropout(params['dropout_cnn_block_two']),
                     
                    Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
                    Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
                    MaxPool2D(),
                    Dropout(params['dropout_cnn_block_three']),
                    
                    Flatten(),
                     
                    Dense(1024, activation='relu'),
                    Dropout(params['dropout_dense_block_one']),
                    
                    Dense(1024, activation='relu'),
                    Dropout(params['dropout_dense_block_two']),
                    
                    Dense(num_classes, activation='softmax')
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  model.fit(
      X_train,
      y_train,
      batch_size=int(params.get('batch_size', 128)),
      epochs=5,
      verbose=0,
      )
  
  accuracy = model.evaluate(X_test, y_test)[0]
  print(params, 'accuracy={}'.format(accuracy))
  
  return {'loss': -accuracy, 'status': STATUS_OK, 'model': model}

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three': hp.uniform('dropout_cnn_block_three', 0.3, 0.5),
    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7)
}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.2385 - accuracy: 0.5000
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.5223 - accuracy: 0.7933
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.6705 - accuracy: 0.7943
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.4872 - accuracy: 0.8568
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.5140 - accuracy: 0.8249
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.4549 - accuracy: 0.8438
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.4056 - accuracy: 0.8617
#
#  84/138 [=================>............]
#  - ETA: 0s - loss: 0.3609 - accuracy: 0.8791
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.3294 - accuracy: 0.8908
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.3919 - accuracy: 0.8665
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.3656 - accuracy: 0.8787
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 0.3487 - accuracy: 0.8804
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.3298 - accuracy: 0.8871
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.4193226122386426, 'dropout_cnn_block_three': 0.31528962022196233, 'dropout_cnn_block_two': 0.34770371703810854, 'dropout_dense_block_one': 0.6790467413141563, 'dropout_dense_block_two': 0.6939331409171935}
# accuracy=0.32977327704429626
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.8659 - accuracy: 0.9062
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.5884 - accuracy: 0.8341
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 0.7884 - accuracy: 0.8288
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.6444 - accuracy: 0.8568
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.7395 - accuracy: 0.7949
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.6489 - accuracy: 0.8247
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.6108 - accuracy: 0.8442
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.5371 - accuracy: 0.8630
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.5029 - accuracy: 0.8743
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.5447 - accuracy: 0.8462
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.5468 - accuracy: 0.8429
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 0.4984 - accuracy: 0.8570
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 0.4858 - accuracy: 0.8605
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.4757 - accuracy: 0.8644
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.3804099179909694, 'dropout_cnn_block_three': 0.367882497669509, 'dropout_cnn_block_two': 0.39553550102645074, 'dropout_dense_block_one': 0.6548541972950765, 'dropout_dense_block_two': 0.6712105925945198}
# accuracy=0.4757053554058075
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.3641 - accuracy: 0.5938
#
#  10/138 [=>............................]
#  - ETA: 0s - loss: 0.9294 - accuracy: 0.8281
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.9323 - accuracy: 0.7917
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 0.9985 - accuracy: 0.7964
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.9585 - accuracy: 0.7798
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.9729 - accuracy: 0.7529
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.8868 - accuracy: 0.7630
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 0.8113 - accuracy: 0.7796
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.7731 - accuracy: 0.7809
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.7119 - accuracy: 0.8005
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.7937 - accuracy: 0.7665
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.7666 - accuracy: 0.7709
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.7027 - accuracy: 0.7902
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.6952 - accuracy: 0.8014
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.6952 - accuracy: 0.8014
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.4190749793158905, 'dropout_cnn_block_three': 0.4622764757797101, 'dropout_cnn_block_two': 0.4485805122061619, 'dropout_dense_block_one': 0.39752494228371615, 'dropout_dense_block_two': 0.5582348316667081}
# accuracy=0.6952400803565979
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.8161 - accuracy: 0.4375
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.3245 - accuracy: 0.8918
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 0.2770 - accuracy: 0.9112
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.1976 - accuracy: 0.9383
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.2580 - accuracy: 0.9216
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.2276 - accuracy: 0.9319
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.2366 - accuracy: 0.9256
#
#  82/138 [================>.............]
#  - ETA: 0s - loss: 0.2053 - accuracy: 0.9356
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.1872 - accuracy: 0.9412
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.1974 - accuracy: 0.9417
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.1872 - accuracy: 0.9448
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.1729 - accuracy: 0.9494
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.1639 - accuracy: 0.9523
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1631 - accuracy: 0.9526
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.4768485299774511, 'dropout_cnn_block_three': 0.4414287556458768, 'dropout_cnn_block_two': 0.35638135605895993, 'dropout_dense_block_one': 0.3957356012815103, 'dropout_dense_block_two': 0.38874063983035395}
# accuracy=0.16311345994472504
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.7777 - accuracy: 0.8438
#
#  15/138 [==>...........................]
#  - ETA: 0s - loss: 0.5610 - accuracy: 0.8438
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 1.1344 - accuracy: 0.8079
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.8602 - accuracy: 0.8357
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.9243 - accuracy: 0.7623
#
#  62/138 [============>.................]
#  - ETA: 0s - loss: 0.8085 - accuracy: 0.7903
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.7246 - accuracy: 0.8138
#
#  85/138 [=================>............]
#  - ETA: 0s - loss: 0.6579 - accuracy: 0.8290
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.6009 - accuracy: 0.8428
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.6443 - accuracy: 0.8224
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.5926 - accuracy: 0.8380
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.6012 - accuracy: 0.8292
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5968 - accuracy: 0.8283
#
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.4954448618750757, 'dropout_cnn_block_three': 0.49222086600268317, 'dropout_cnn_block_two': 0.4407213421720566, 'dropout_dense_block_one': 0.4721805062086034, 'dropout_dense_block_two': 0.4902849759320247}
# accuracy=0.5968295335769653
#   1/138 [..............................]
#  - ETA: 0s - loss: 1
#
# 113/138 [=======================>......]
#  - ETA: 0s - loss: 0.1679 - accuracy: 0.9527
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.1573 - accuracy: 0.9559
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.1559 - accuracy: 0.9560
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1560 - accuracy: 0.9558
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.47607739537042554, 'dropout_cnn_block_three': 0.31954255808106014, 'dropout_cnn_block_two': 0.3680379893481774, 'dropout_dense_block_one': 0.6601100974893029, 'dropout_dense_block_two': 0.3488820184321524}
# accuracy=0.15597622096538544
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.3844 - accuracy: 0.7812
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.1398 - accuracy: 0.9487
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.4300 - accuracy: 0.9207
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.2923 - accuracy: 0.9463
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.3065 - accuracy: 0.9344
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.2631 - accuracy: 0.9414
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.2261 - accuracy: 0.9489
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 0.1992 - accuracy: 0.9544
#
# 101/138 [====================>.........]
#  - ETA: 0s - loss: 0.1844 - accuracy: 0.9592
#
# 113/138 [=======================>......]
#  - ETA: 0s - loss: 0.1963 - accuracy: 0.9524
#
# 125/138 [==========================>...]
#  - ETA: 0s - loss: 0.1780 - accuracy: 0.9567
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.1645 - accuracy: 0.9601
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.1704 - accuracy: 0.9587
#
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.3058934918138071, 'dropout_cnn_block_three': 0.49871597686193164, 'dropout_cnn_block_two': 0.4120056236985211, 'dropout_dense_block_one': 0.49966319492333655, 'dropout_dense_block_two': 0.4903518541808075}
# accuracy=0.17040415108203888
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.7435 - accuracy: 0.6875
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.2272 - accuracy: 0.9519
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.3348 - accuracy: 0.9137
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.4907 - accuracy: 0.9043
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 0.4294 - accuracy: 0.9107
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.4479 - accuracy: 0.8950
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.4040 - accuracy: 0.9023
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 0.3856 - accuracy: 0.9003
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.3881 - accuracy: 0.9021
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.3495 - accuracy: 0.9131
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.3785 - accuracy: 0.8990
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.3511 - accuracy: 0.9065
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.3354 - accuracy: 0.9067
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3281 - accuracy: 0.9093
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.4096045158408153, 'dropout_cnn_block_three': 0.35454908248950573, 'dropout_cnn_block_two': 0.37423535235022437, 'dropout_dense_block_one': 0.4973281558796619, 'dropout_dense_block_two': 0.42814189600514013}
# accuracy=0.32805177569389343
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.6944 - accuracy: 0.6250
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.2190 - accuracy: 0.9263
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.8458 - accuracy: 0.9026
#
#  38/138 [=======>......................]
#  - ETA: 0s - loss: 0.5908 - accuracy: 0.9285
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.5738 - accuracy: 0.9050
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.4926 - accuracy: 0.9162
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 0.4269 - accuracy: 0.9269
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.5586 - accuracy: 0.8105
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.6304 - accuracy: 0.7836
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.5912 - accuracy: 0.7900
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.5564 - accuracy: 0.8022
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.5362 - accuracy: 0.8107
#
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.4312378867574196, 'dropout_cnn_block_three': 0.47792437740426635, 'dropout_cnn_block_two': 0.43053031622266685, 'dropout_dense_block_one': 0.6909823482542445, 'dropout_dense_block_two': 0.5605807356531978}
# accuracy=0.5361917018890381
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9269 - accuracy: 0.0312
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.6797 - accuracy: 0.7885
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 1.2331 - accuracy: 0.7174
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 1.1263 - accuracy: 0.6932
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 1.0792 - accuracy: 0.6996
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 1.0965 - accuracy: 0.6852
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 1.0143 - accuracy: 0.6993
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.9137 - accuracy: 0.7147
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 0.8570 - accuracy: 0.7372
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.8136 - accuracy: 0.7589
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.8985 - accuracy: 0.7242
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.8355 - accuracy: 0.7403
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.7913 - accuracy: 0.7526
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.7732 - accuracy: 0.7639
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.46012639552722173, 'dropout_cnn_block_three': 0.4220842318800667, 'dropout_cnn_block_two': 0.4666158967196575, 'dropout_dense_block_one': 0.5305502292639966, 'dropout_dense_block_two': 0.6471292528875415}
# accuracy=0.7732480764389038
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.3716 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.9647 - accuracy: 0.7668
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 1.3691 - accuracy: 0.6302
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 1.1728 - accuracy: 0.6476
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 1.2529 - accuracy: 0.6237
#
#  60/138 [============>.................]
#  - ETA: 0s - loss: 1.1880 - accuracy: 0.6240
#
#  72/138 [==============>...............]
#  - ETA: 0s - loss: 1.0727 - accuracy: 0.6649
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.9728 - accuracy: 0.6999
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.8807 - accuracy: 0.7320
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.9267 - accuracy: 0.6887
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.8918 - accuracy: 0.6959
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.8266 - accuracy: 0.7178
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.8299 - accuracy: 0.7263
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.8299 - accuracy: 0.7263
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.4960963885632713, 'dropout_cnn_block_three': 0.38738479414458177, 'dropout_cnn_block_two': 0.4646818961014639, 'dropout_dense_block_one': 0.5327430609419388, 'dropout_dense_block_two': 0.6999679514684082}
# accuracy=0.8299427032470703
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.0324 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 1.1722 - accuracy: 0.6202
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 1.3439 - accuracy: 0.5703
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 1.0741 - accuracy: 0.6491
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 1.0762 - accuracy: 0.6413
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 1.1652 - accuracy: 0.6127
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 1.0942 - accuracy: 0.6167
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.9672 - accuracy: 0.6630
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.9219 - accuracy: 0.6786
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.9247 - accuracy: 0.6757
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.9182 - accuracy: 0.6785
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 0.8508 - accuracy: 0.7026
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 0.8341 - accuracy: 0.7108
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.8251 - accuracy: 0.7170
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.4999000517315759, 'dropout_cnn_block_three': 0.3844387105081883, 'dropout_cnn_block_two': 0.4828418151546081, 'dropout_dense_block_one': 0.4542371070699995, 'dropout_dense_block_two': 0.6982718683124373}
# accuracy=0.8251013159751892
# 100%|██████████| 30/30 [10:09<00:00, 20.32s/it, best loss: -1.113366961479187]
